# %%
import pandas as pd

# %%
cleaned_df = pd.read_csv('cleaned_data.csv')

# %%
cleaned_df = cleaned_df.sort_values(by='CGPA')

# %%
# cleaned_df.info()
df1 = cleaned_df[cleaned_df['CGPA']>=7.5]

# %%
df1.info()
df1.to_csv('data_high.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 52 to 0
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          55 non-null     object
#  1   CGPA                                            55 non-null     float64
#  2   10th Class Board                                55 non-null     object
#  3   10th Class Science Marks (out of 100)           55 non-null     int64
#  4   10th Class Maths Marks (out of 100)             55 non-null     int64
#  5   10th Class English/Language Marks (out of 100)  55 non-null     int64
#  6   10th Class Overall Percentage                   55 non-null     float64
#  7   12th Class School Category                      55 non-null     object
#  8   12th Class Board                                55 non-null     object
# ...

# %%
df2 = cleaned_df[(cleaned_df['CGPA']>=6.5) & (cleaned_df['CGPA']<7.5)]
df2.info()
df2.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67 entries, 118 to 55
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          67 non-null     object
#  1   CGPA                                            67 non-null     float64
#  2   10th Class Board                                67 non-null     object
#  3   10th Class Science Marks (out of 100)           67 non-null     int64
#  4   10th Class Maths Marks (out of 100)             67 non-null     int64
#  5   10th Class English/Language Marks (out of 100)  67 non-null     int64
#  6   10th Class Overall Percentage                   67 non-null     float64
#  7   12th Class School Category                      67 non-null     object
#  8   12th Class Board                                67 non-null     object
# ...

# %%
df2.to_csv('data_mid.csv',index=False)

# %%
df3 = cleaned_df[cleaned_df['CGPA']<6.5]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 156 to 127
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          35 non-null     object
#  1   CGPA                                            35 non-null     float64
#  2   10th Class Board                                35 non-null     object
#  3   10th Class Science Marks (out of 100)           35 non-null     int64
#  4   10th Class Maths Marks (out of 100)             35 non-null     int64
#  5   10th Class English/Language Marks (out of 100)  35 non-null     int64
#  6   10th Class Overall Percentage                   35 non-null     float64
#  7   12th Class School Category                      35 non-null     object
#  8   12th Class Board                                35 non-null     object
# ...

# %%
df3.to_csv('data_low.csv',index=False)
