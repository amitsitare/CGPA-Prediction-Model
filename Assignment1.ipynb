# %%
import pandas as pd
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8356\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\dell\OneDrive\Desktop\c1\CGPA-Prediction-Model\Anonymised_2028_Batch_Marks.csv")

# %%
df.shape
# Out:
# (158, 22)

# %%
df
# Out:
#      Gender  CGPA 10th Class Board 10th Class Science Marks (out of 100)  \
# 0    Female   8.6             ICSE                                    83
# 1      Male   8.6      State Board                                    93
# 2      Male   8.6             CBSE                                    95
# 3      Male   8.6             CBSE                                    98
# 4      Male   8.4             CBSE                                    80
# ..      ...   ...              ...                                   ...
# 153    Male   5.3             CBSE                                    78
# 154    Male   5.0             CBSE                                    81
# 155    Male   4.9      State Board                                 10/10
# 156    Male   3.1             CBSE                                    91
# 157    Male   0.2             CBSE                                    77
#
#     10th Class Maths Marks (out of 100)  \
# 0                                    89
# ...

# %%
df.head(10)
# Out:
#    Gender  CGPA 10th Class Board 10th Class Science Marks (out of 100)  \
# 0  Female   8.6             ICSE                                    83
# 1    Male   8.6      State Board                                    93
# 2    Male   8.6             CBSE                                    95
# 3    Male   8.6             CBSE                                    98
# 4    Male   8.4             CBSE                                    80
# 5  Female   8.3             CBSE                                    94
# 6    Male   8.3      State Board                                    98
# 7    Male   8.2             CBSE                                    92
# 8    Male   8.2             CBSE                                    89
# 9  Female   8.2             ICSE                                    93
#
#   10th Class Maths Marks (out of 100)  \
# 0                                  89
# 1                                  79
# 2                                  99
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          158 non-null    object
#  1   CGPA                                            158 non-null    float64
#  2   10th Class Board                                158 non-null    object
#  3   10th Class Science Marks (out of 100)           158 non-null    object
#  4   10th Class Maths Marks (out of 100)             158 non-null    object
#  5   10th Class English/Language Marks (out of 100)  158 non-null    object
#  6   10th Class Overall Percentage                   158 non-null    object
#  7   12th Class School Category                      158 non-null    object
#  8   12th Class Board                                158 non-null    object
# ...

# %%
df.describe()
# Out:
#              CGPA  JEE Mains Session 1 Maths Percentile  \
# count  158.000000                            158.000000
# mean     7.027848                             63.964557
# std      0.992512                             21.462683
# min      0.200000                              4.100000
# 25%      6.500000                             47.900000
# 50%      7.100000                             68.300000
# 75%      7.700000                             82.650000
# max      8.600000                             96.300000
#
#        JEE Mains Session 1 Physics  Percentile  \
# count                               158.000000
# mean                                 80.843671
# std                                  13.502071
# min                                  22.300000
# 25%                                  74.400000
# 50%                                  83.750000
# 75%                                  90.875000
# max                                  97.800000
#
# ...
